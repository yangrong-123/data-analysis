# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 10.1 GroupBy机制

# %%
df = pd.DataFrame({
    'key1':list('aabba'),
    'key2':'one two one two one'.split(),
    'data1': np.random.randn(5),
    'data2': np.random.randn(5)
})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.257300 -0.372383
# 1    a  two  0.599165 -0.745518
# 2    b  one -0.039337 -0.366200
# 3    b  two -0.791765  1.923449
# 4    a  one  0.530950  1.718644

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped

# %%
list(grouped)
# Out:
# [('a',
#   0   -0.257300
#   1    0.599165
#   4    0.530950
#   Name: data1, dtype: float64),
#  ('b',
#   2   -0.039337
#   3   -0.791765
#   Name: data1, dtype: float64)]

# %%
grouped.mean()
# Out:
# key1
# a    0.290938
# b   -0.415551
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df['key1'], df['key2']])

# %%
list(means)
# Out:
# [(('a', 'one'),
#   0   -0.25730
#   4    0.53095
#   Name: data1, dtype: float64),
#  (('a', 'two'),
#   1    0.599165
#   Name: data1, dtype: float64),
#  (('b', 'one'),
#   2   -0.039337
#   Name: data1, dtype: float64),
#  (('b', 'two'),
#   3   -0.791765
#   Name: data1, dtype: float64)]

# %%
means = means.mean()

# %%
means
# Out:
# key1  key2
# a     one     0.136825
#       two     0.599165
# b     one    -0.039337
#       two    -0.791765
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a     0.136825  0.599165
# b    -0.039337 -0.791765

# %%
states = np.array('ohio california california ohio ohio'.split())

# %%
states
# Out:
# array(['ohio', 'california', 'california', 'ohio', 'ohio'], dtype='<U10')

# %%
years = np.array([2005, 2005, 2006, 2005, 2006])

# %%
list(df['data1'].groupby([states, years]))
# Out:
# [(('california', 2005),
#   1    0.599165
#   Name: data1, dtype: float64),
#  (('california', 2006),
#   2   -0.039337
#   Name: data1, dtype: float64),
#  (('ohio', 2005),
#   0   -0.257300
#   3   -0.791765
#   Name: data1, dtype: float64),
#  (('ohio', 2006),
#   4    0.53095
#   Name: data1, dtype: float64)]

# %%
list(df.groupby('key1'))
# Out:
# [('a',
#     key1 key2     data1     data2
#   0    a  one -0.257300 -0.372383
#   1    a  two  0.599165 -0.745518
#   4    a  one  0.530950  1.718644),
#  ('b',
#     key1 key2     data1     data2
#   2    b  one -0.039337 -0.366200
#   3    b  two -0.791765  1.923449)]

# %%
df.groupby('key1').mean()
# Out:
#          data1     data2
# key1
# a     0.290938  0.200248
# b    -0.415551  0.778624

# %%
(-0.8+1.9+1.6)/3
# Out:
# 0.9

# %%
df.groupby(['key1', 'key2']).mean()
# Out:
#               data1     data2
# key1 key2
# a    one   0.136825  0.673131
#      two   0.599165 -0.745518
# b    one  -0.039337 -0.366200
#      two  -0.791765  1.923449

# %%
list(df.groupby(['key1', 'key2']))
# Out:
# [(('a', 'one'),
#     key1 key2    data1     data2
#   0    a  one -0.25730 -0.372383
#   4    a  one  0.53095  1.718644),
#  (('a', 'two'),
#     key1 key2     data1     data2
#   1    a  two  0.599165 -0.745518),
#  (('b', 'one'),
#     key1 key2     data1   data2
#   2    b  one -0.039337 -0.3662),
#  (('b', 'two'),
#     key1 key2     data1     data2
#   3    b  two -0.791765  1.923449)]

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %% [markdown]
# ## 10.1.1 遍历各分组

# %%
for k,v in df.groupby('key1'):
    print(k)
    print(v)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one -0.257300 -0.372383
# 1    a  two  0.599165 -0.745518
# 4    a  one  0.530950  1.718644
# b
#   key1 key2     data1     data2
# 2    b  one -0.039337 -0.366200
# 3    b  two -0.791765  1.923449

# %%
for k,v in df.groupby(['key1', 'key2']):
    print(k)
    print(v)
# Out:
# ('a', 'one')
#   key1 key2    data1     data2
# 0    a  one -0.25730 -0.372383
# 4    a  one  0.53095  1.718644
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two  0.599165 -0.745518
# ('b', 'one')
#   key1 key2     data1   data2
# 2    b  one -0.039337 -0.3662
# ('b', 'two')
#   key1 key2     data1     data2
# 3    b  two -0.791765  1.923449

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.257300 -0.372383
# 1    a  two  0.599165 -0.745518
# 2    b  one -0.039337 -0.366200
# 3    b  two -0.791765  1.923449
# 4    a  one  0.530950  1.718644

# %%
list(df.groupby('key1'))[0]
# Out:
# ('a',
#    key1 key2     data1     data2
#  0    a  one -0.257300 -0.372383
#  1    a  two  0.599165 -0.745518
#  4    a  one  0.530950  1.718644)

# %%
dict(list(df.groupby('key1')))['a']
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.257300 -0.372383
# 1    a  two  0.599165 -0.745518
# 4    a  one  0.530950  1.718644

# %%
df.dtypes
# Out:
# key1      object
# key2      object
# data1    float64
# data2    float64
# dtype: object

# %%
dict(list(df.groupby(df.dtypes, axis=1)))
# Out:
# {dtype('float64'):       data1     data2
#  0 -0.257300 -0.372383
#  1  0.599165 -0.745518
#  2 -0.039337 -0.366200
#  3 -0.791765  1.923449
#  4  0.530950  1.718644,
#  dtype('O'):   key1 key2
#  0    a  one
#  1    a  two
#  2    b  one
#  3    b  two
#  4    a  one}

# %% [markdown]
# ## 10.1.2 选择一列或所有列的子集

# %%
list(df.groupby('key1')['data1'])
# Out:
# [('a',
#   0   -0.257300
#   1    0.599165
#   4    0.530950
#   Name: data1, dtype: float64),
#  ('b',
#   2   -0.039337
#   3   -0.791765
#   Name: data1, dtype: float64)]

# %%
list(df.groupby('key1'))
# Out:
# [('a',
#     key1 key2     data1     data2
#   0    a  one -0.257300 -0.372383
#   1    a  two  0.599165 -0.745518
#   4    a  one  0.530950  1.718644),
#  ('b',
#     key1 key2     data1     data2
#   2    b  one -0.039337 -0.366200
#   3    b  two -0.791765  1.923449)]

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.257300 -0.372383
# 1    a  two  0.599165 -0.745518
# 2    b  one -0.039337 -0.366200
# 3    b  two -0.791765  1.923449
# 4    a  one  0.530950  1.718644

# %%
df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one   0.673131
#      two  -0.745518
# b    one  -0.366200
#      two   1.923449

# %% [markdown]
# ## 10.1.3 使用字典和Series分组

# %%
people = pd.DataFrame(np.random.randn(5,5),
                     columns=list('abcde'),
                     index='koe steve wes jim travis'.split())

# %%
people
# Out:
#                a         b         c         d         e
# koe    -0.062005 -0.258812 -0.025250 -1.110413  0.355332
# steve  -0.752729 -0.465500 -0.665184 -0.611505  0.090385
# wes    -1.907472  0.222614  0.009567  1.070332 -0.258682
# jim    -1.053589 -1.115376  0.420870  0.110676 -0.151446
# travis  1.321720  0.543888 -0.706025  1.233239 -0.058528

# %%
mapping = {
    'a':'red', 'b':'red', 'c':'blue',
    'd':'blue', 'e':'red', 'f':'orange'
}

# %%
mapping
# Out:
# {'a': 'red', 'b': 'red', 'c': 'blue', 'd': 'blue', 'e': 'red', 'f': 'orange'}

# %%
list(people.groupby(mapping, axis=1))
# Out:
# [('blue',
#                  c         d
#   koe    -0.025250 -1.110413
#   steve  -0.665184 -0.611505
#   wes     0.009567  1.070332
#   jim     0.420870  0.110676
#   travis -0.706025  1.233239),
#  ('red',
#                  a         b         e
#   koe    -0.062005 -0.258812  0.355332
#   steve  -0.752729 -0.465500  0.090385
#   wes    -1.907472  0.222614 -0.258682
#   jim    -1.053589 -1.115376 -0.151446
#   travis  1.321720  0.543888 -0.058528)]

# %%
people.groupby(mapping, axis=1).sum()
# Out:
#             blue       red
# koe    -1.135663  0.034515
# steve  -1.276690 -1.127844
# wes     1.079899 -1.943539
# jim     0.531546 -2.320411
# travis  0.527213  1.807080

# %%
people.groupby(mapping, axis=1).count()
# Out:
#         blue  red
# koe        2    3
# steve      2    3
# wes        2    3
# jim        2    3
# travis     2    3

# %%
people.groupby(mapping, axis=1).size()
# Out:
# blue    2
# red     3
# dtype: int64

# %%
map_series = pd.Series(mapping)

# %%
map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %% [markdown]
# ## 10.1.4 使用函数分组

# %%
list(people.groupby(len))
# Out:
# [(3,
#               a         b         c         d         e
#   koe -0.062005 -0.258812 -0.025250 -1.110413  0.355332
#   wes -1.907472  0.222614  0.009567  1.070332 -0.258682
#   jim -1.053589 -1.115376  0.420870  0.110676 -0.151446),
#  (5,
#                 a       b         c         d         e
#   steve -0.752729 -0.4655 -0.665184 -0.611505  0.090385),
#  (6,
#                 a         b         c         d         e
#   travis  1.32172  0.543888 -0.706025  1.233239 -0.058528)]

# %%
list(people.groupby([len, 'one one one two two'.split()]))
# Out:
# [((3, 'one'),
#               a         b         c         d         e
#   koe -0.062005 -0.258812 -0.025250 -1.110413  0.355332
#   wes -1.907472  0.222614  0.009567  1.070332 -0.258682),
#  ((3, 'two'),
#               a         b        c         d         e
#   jim -1.053589 -1.115376  0.42087  0.110676 -0.151446),
#  ((5, 'one'),
#                 a       b         c         d         e
#   steve -0.752729 -0.4655 -0.665184 -0.611505  0.090385),
#  ((6, 'two'),
#                 a         b         c         d         e
#   travis  1.32172  0.543888 -0.706025  1.233239 -0.058528)]

# %%
people
# Out:
#                a         b         c         d         e
# koe    -0.062005 -0.258812 -0.025250 -1.110413  0.355332
# steve  -0.752729 -0.465500 -0.665184 -0.611505  0.090385
# wes    -1.907472  0.222614  0.009567  1.070332 -0.258682
# jim    -1.053589 -1.115376  0.420870  0.110676 -0.151446
# travis  1.321720  0.543888 -0.706025  1.233239 -0.058528

# %% [markdown]
# ## 10.1.5 根据索引层级分组

# %%
columns = pd.MultiIndex.from_arrays([
    ['us','us','us','jp','jp'], [1,3,5,1,3]
],
    names=['cty', 'tenor']
)

# %%
columns
# Out:
# MultiIndex([('us', 1),
#             ('us', 3),
#             ('us', 5),
#             ('jp', 1),
#             ('jp', 3)],
#            names=['cty', 'tenor'])

# %%
hier = pd.DataFrame(np.random.randn(4,5), columns=columns)

# %%
hier
# Out:
# cty          us                            jp
# tenor         1         3         5         1         3
# 0     -0.457169  0.123562 -0.380203 -0.128963  0.009367
# 1     -0.648602  0.569458  0.244311  0.273475 -1.536725
# 2      0.566489  0.132911  0.065392  0.800078 -1.688022
# 3      1.492073  1.823024 -0.115152 -0.394936  0.693666

# %%
list(hier.groupby(level='cty', axis=1))
# Out:
# [('jp',
#   cty          jp
#   tenor         1         3
#   0     -0.128963  0.009367
#   1      0.273475 -1.536725
#   2      0.800078 -1.688022
#   3     -0.394936  0.693666),
#  ('us',
#   cty          us
#   tenor         1         3         5
#   0     -0.457169  0.123562 -0.380203
#   1     -0.648602  0.569458  0.244311
#   2      0.566489  0.132911  0.065392
#   3      1.492073  1.823024 -0.115152)]

# %%
hier.groupby(level='cty', axis=1).count()
# Out:
# cty  jp  us
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %% [markdown]
# # 10.2 数据聚合

# %%
df = pd.DataFrame({
    'key1':list('aabba'),
    'key2':'one two one two one'.split(),
    'data1': np.random.randn(5),
    'data2': np.random.randn(5)
})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -2.268259  0.016101
# 1    a  two -0.182174 -0.507311
# 2    b  one -1.199741  1.942404
# 3    b  two  0.174576  0.600035
# 4    a  one -1.569827  0.374850

# %%
grouped = df.groupby('key1')

# %%
list(grouped)
# Out:
# [('a',
#     key1 key2     data1     data2
#   0    a  one -2.268259  0.016101
#   1    a  two -0.182174 -0.507311
#   4    a  one -1.569827  0.374850),
#  ('b',
#     key1 key2     data1     data2
#   2    b  one -1.199741  1.942404
#   3    b  two  0.174576  0.600035)]

# %%
list(grouped['data1'])
# Out:
# [('a',
#   0   -2.268259
#   1   -0.182174
#   4   -1.569827
#   Name: data1, dtype: float64),
#  ('b',
#   2   -1.199741
#   3    0.174576
#   Name: data1, dtype: float64)]

# %%
grouped['data1'].quantile(0.9)
# Out:
# key1
# a   -0.459704
# b    0.037145
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()

# %%
grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     2.086086  0.882162
# b     1.374317  1.342369

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0 -1.340087  1.061849 -2.268259 -1.919043 -1.569827 -0.876000
# b      2.0 -0.512582  0.971789 -1.199741 -0.856162 -0.512582 -0.169003
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a    -0.182174   3.0 -0.038787  0.443635 -0.507311 -0.245605  0.016101
# b     0.174576   2.0  1.271219  0.949198  0.600035  0.935627  1.271219
#
#
#            75%       max
# key1
# a     0.195475  0.374850
# b     1.606812  1.942404

# %%
grouped['data1'].quantile(0.75)
# Out:
# key1
# a   -0.876000
# b   -0.169003
# Name: data1, dtype: float64

# %% [markdown]
# ## 10.2.1 逐列及多函数应用

# %%
tips = pd.read_csv('examples/tips.csv')

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61     No   Sun  Dinner     4  0.146808
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00     No  Thur  Dinner     2  0.159744
#
# [244 rows x 7 columns]

# %%
grouped = tips.groupby(['day', 'smoker'])

# %%
list(grouped)
# Out:
# [(('Fri', 'No'),
#        total_bill   tip smoker  day    time  size   tip_pct
#   91        22.49  3.50     No  Fri  Dinner     2  0.155625
#   94        22.75  3.25     No  Fri  Dinner     2  0.142857
#   99        12.46  1.50     No  Fri  Dinner     2  0.120385
#   223       15.98  3.00     No  Fri   Lunch     3  0.187735),
#  (('Fri', 'Yes'),
#        total_bill   tip smoker  day    time  size   tip_pct
#   90        28.97  3.00    Yes  Fri  Dinner     2  0.103555
#   92         5.75  1.00    Yes  Fri  Dinner     2  0.173913
#   93        16.32  4.30    Yes  Fri  Dinner     2  0.263480
#   95        40.17  4.73    Yes  Fri  Dinner     4  0.117750
#   96        27.28  4.00    Yes  Fri  Dinner     2  0.146628
#   97        12.03  1.50    Yes  Fri  Dinner     2  0.124688
#   98        21.01  3.00    Yes  Fri  Dinner     2  0.142789
#   100       11.35  2.50    Yes  Fri  Dinner     2  0.220264
#   101       15.38  3.00    Yes  Fri  Dinner     2  0.195059
# ...

# %%
grouped.min()
# Out:
#              total_bill   tip    time  size   tip_pct
# day  smoker
# Fri  No           12.46  1.50  Dinner     2  0.120385
#      Yes           5.75  1.00  Dinner     1  0.103555
# Sat  No            7.25  1.00  Dinner     1  0.056797
#      Yes           3.07  1.00  Dinner     1  0.035638
# Sun  No            8.77  1.01  Dinner     2  0.059447
#      Yes           7.25  1.50  Dinner     2  0.065660
# Thur No            7.51  1.25  Dinner     1  0.072961
#      Yes          10.34  2.00   Lunch     2  0.090014

# %%
grouped['tip_pct'].agg('min')
# Out:
# day   smoker
# Fri   No        0.120385
#       Yes       0.103555
# Sat   No        0.056797
#       Yes       0.035638
# Sun   No        0.059447
#       Yes       0.065660
# Thur  No        0.072961
#       Yes       0.090014
# Name: tip_pct, dtype: float64

# %%
grouped['tip_pct'].agg(['min', 'max', 'mean', 'std', peak_to_peak])
# Out:
#                   min       max      mean       std  peak_to_peak
# day  smoker
# Fri  No      0.120385  0.187735  0.151650  0.028123      0.067349
#      Yes     0.103555  0.263480  0.174783  0.051293      0.159925
# Sat  No      0.056797  0.291990  0.158048  0.039767      0.235193
#      Yes     0.035638  0.325733  0.147906  0.061375      0.290095
# Sun  No      0.059447  0.252672  0.160113  0.042347      0.193226
#      Yes     0.065660  0.710345  0.187250  0.154134      0.644685
# Thur No      0.072961  0.266312  0.160298  0.038774      0.193350
#      Yes     0.090014  0.241255  0.163863  0.039389      0.151240

# %%
grouped['tip_pct'].agg([('foo', 'mean'), ('bar', np.std)])
# Out:
#                   foo       bar
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
functions = ['count', 'mean', 'max']

# %%
result = grouped[['tip_pct', 'total_bill']].agg(functions)

# %%
result
# Out:
#             tip_pct                     total_bill
#               count      mean       max      count       mean    max
# day  smoker
# Fri  No           4  0.151650  0.187735          4  18.420000  22.75
#      Yes         15  0.174783  0.263480         15  16.813333  40.17
# Sat  No          45  0.158048  0.291990         45  19.661778  48.33
#      Yes         42  0.147906  0.325733         42  21.276667  50.81
# Sun  No          57  0.160113  0.252672         57  20.506667  48.17
#      Yes         19  0.187250  0.710345         19  24.120000  45.35
# Thur No          45  0.160298  0.266312         45  17.113111  41.19
#      Yes         17  0.163863  0.241255         17  19.190588  43.11

# %%
result['tip_pct']
# Out:
#              count      mean       max
# day  smoker
# Fri  No          4  0.151650  0.187735
#      Yes        15  0.174783  0.263480
# Sat  No         45  0.158048  0.291990
#      Yes        42  0.147906  0.325733
# Sun  No         57  0.160113  0.252672
#      Yes        19  0.187250  0.710345
# Thur No         45  0.160298  0.266312
#      Yes        17  0.163863  0.241255

# %%
ftuples = [('durchschnitt', 'mean'), ('abweichung', np.var)]

# %%
grouped[['tip_pct', 'total_bill']].agg(ftuples)
# Out:
#                  tip_pct              total_bill
#             durchschnitt abweichung durchschnitt  abweichung
# day  smoker
# Fri  No         0.151650   0.000791    18.420000   25.596333
#      Yes        0.174783   0.002631    16.813333   82.562438
# Sat  No         0.158048   0.001581    19.661778   79.908965
#      Yes        0.147906   0.003767    21.276667  101.387535
# Sun  No         0.160113   0.001793    20.506667   66.099980
#      Yes        0.187250   0.023757    24.120000  109.046044
# Thur No         0.160298   0.001503    17.113111   59.625081
#      Yes        0.163863   0.001551    19.190588   69.808518

# %%
grouped.agg({'tip':np.max, 'size':'sum'})
# Out:
#                tip  size
# day  smoker
# Fri  No       3.50     9
#      Yes      4.73    31
# Sat  No       9.00   115
#      Yes     10.00   104
# Sun  No       6.00   167
#      Yes      6.50    49
# Thur No       6.70   112
#      Yes      5.00    40

# %%
grouped.agg({
    'tip_pct':['min','max','size','std'],
    'size': 'sum'
})
# Out:
#               tip_pct                          size
#                   min       max size       std  sum
# day  smoker
# Fri  No      0.120385  0.187735    4  0.028123    9
#      Yes     0.103555  0.263480   15  0.051293   31
# Sat  No      0.056797  0.291990   45  0.039767  115
#      Yes     0.035638  0.325733   42  0.061375  104
# Sun  No      0.059447  0.252672   57  0.042347  167
#      Yes     0.065660  0.710345   19  0.154134   49
# Thur No      0.072961  0.266312   45  0.038774  112
#      Yes     0.090014  0.241255   17  0.039389   40

# %% [markdown]
# ## 10.2.2 返回不含行索引的聚合数据

# %%
tips.groupby(['day', 'smoker'], as_index=False).mean()
# Out:
#     day smoker  total_bill       tip      size   tip_pct
# 0   Fri     No   18.420000  2.812500  2.250000  0.151650
# 1   Fri    Yes   16.813333  2.714000  2.066667  0.174783
# 2   Sat     No   19.661778  3.102889  2.555556  0.158048
# 3   Sat    Yes   21.276667  2.875476  2.476190  0.147906
# 4   Sun     No   20.506667  3.167895  2.929825  0.160113
# 5   Sun    Yes   24.120000  3.516842  2.578947  0.187250
# 6  Thur     No   17.113111  2.673778  2.488889  0.160298
# 7  Thur    Yes   19.190588  3.030000  2.352941  0.163863

# %%
tips.groupby(['day', 'smoker']).mean().reset_index()
# Out:
#     day smoker  total_bill       tip      size   tip_pct
# 0   Fri     No   18.420000  2.812500  2.250000  0.151650
# 1   Fri    Yes   16.813333  2.714000  2.066667  0.174783
# 2   Sat     No   19.661778  3.102889  2.555556  0.158048
# 3   Sat    Yes   21.276667  2.875476  2.476190  0.147906
# 4   Sun     No   20.506667  3.167895  2.929825  0.160113
# 5   Sun    Yes   24.120000  3.516842  2.578947  0.187250
# 6  Thur     No   17.113111  2.673778  2.488889  0.160298
# 7  Thur    Yes   19.190588  3.030000  2.352941  0.163863

# %% [markdown]
# # 10.3 应用：通用拆分 - 应用 - 联合

# %%
def top(df, n=5, columns='tip_pct'):
    return df.sort_values(by=columns)[-n:]

# %%
top(tips, n=6)
# Out:
#      total_bill   tip smoker  day    time  size   tip_pct
# 109       14.31  4.00    Yes  Sat  Dinner     2  0.279525
# 183       23.17  6.50    Yes  Sun  Dinner     4  0.280535
# 232       11.61  3.39     No  Sat  Dinner     2  0.291990
# 67         3.07  1.00    Yes  Sat  Dinner     1  0.325733
# 178        9.60  4.00    Yes  Sun  Dinner     2  0.416667
# 172        7.25  5.15    Yes  Sun  Dinner     2  0.710345

# %%
list(tips.groupby('smoker'))
# Out:
# [('No',
#        total_bill   tip smoker   day    time  size   tip_pct
#   0         16.99  1.01     No   Sun  Dinner     2  0.059447
#   1         10.34  1.66     No   Sun  Dinner     3  0.160542
#   2         21.01  3.50     No   Sun  Dinner     3  0.166587
#   3         23.68  3.31     No   Sun  Dinner     2  0.139780
#   4         24.59  3.61     No   Sun  Dinner     4  0.146808
#   ..          ...   ...    ...   ...     ...   ...       ...
#   235       10.07  1.25     No   Sat  Dinner     2  0.124131
#   238       35.83  4.67     No   Sat  Dinner     3  0.130338
#   239       29.03  5.92     No   Sat  Dinner     3  0.203927
#   242       17.82  1.75     No   Sat  Dinner     2  0.098204
#   243       18.78  3.00     No  Thur  Dinner     2  0.159744
#
#   [151 rows x 7 columns]),
#  ('Yes',
#        total_bill   tip smoker  day    time  size   tip_pct
#   56        38.01  3.00    Yes  Sat  Dinner     4  0.078927
#   58        11.24  1.76    Yes  Sat  Dinner     2  0.156584
# ...

# %%
tips.groupby('smoker').apply(top)
# Out:
#             total_bill   tip smoker   day    time  size   tip_pct
# smoker
# No     88        24.71  5.85     No  Thur   Lunch     2  0.236746
#        185       20.69  5.00     No   Sun  Dinner     5  0.241663
#        51        10.29  2.60     No   Sun  Dinner     2  0.252672
#        149        7.51  2.00     No  Thur   Lunch     2  0.266312
#        232       11.61  3.39     No   Sat  Dinner     2  0.291990
# Yes    109       14.31  4.00    Yes   Sat  Dinner     2  0.279525
#        183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
#        67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
#        178        9.60  4.00    Yes   Sun  Dinner     2  0.416667
#        172        7.25  5.15    Yes   Sun  Dinner     2  0.710345

# %%
tips.iloc[185:186,:]
# Out:
#      total_bill  tip smoker  day    time  size   tip_pct
# 185       20.69  5.0     No  Sun  Dinner     5  0.241663

# %%
tips.groupby('smoker').agg('sum')
# Out:
#         total_bill     tip  size    tip_pct
# smoker
# No         2897.43  451.77   403  24.058598
# Yes        1930.34  279.81   224  15.177232

# %%
tips.groupby(['smoker','day']).apply(, n=1, columns='total_bill')
# Out:
#   File "<ipython-input-90-b3e9cb63e1e9>", line 1
#     tips.groupby(['smoker','day']).apply(, n=1, columns='total_bill')
#                                          ^
# SyntaxError: invalid syntax

# %%
list(tips.groupby(['smoker','day']))

# %%
tips.groupby('smoker').apply(top).unstack()

# %%
result = tips.groupby('smoker')['tip_pct'].describe()

# %%
result

# %%
list(tips.groupby('smoker')['tip_pct'])

# %%
result.unstack()
# Series

# %%
f = lambda x: x.describe()

# %%
tips.groupby('smoker')['tip_pct'].apply(f)

# %% [markdown]
# ## 10.3.1 压缩分组键

# %%
tips.groupby('smoker', group_keys=False).apply(top)

# %%
tips.groupby('smoker', group_keys=True).apply(top)

# %%
tips.groupby('smoker', as_index=False).apply(top)

# %% [markdown]
# ## 10.3.2 分位数与桶分析

# %%
frame = pd.DataFrame({
    'data1': np.random.randn(1000),
    'data2': np.random.randn(1000)
})

# %%
frame

# %%
quartiles = pd.cut(frame.data1, 4)

# %%
quartiles

# %%
def get_stats(group):
    return {
        'min': group.min(), 'max': group.max(),
        'count': group.count(), 'mean': group.mean()
    }

# %%
grouped = frame.data2.groupby(quartiles)

# %%
list(grouped)

# %%
grouped.apply(get_stats).unstack()

# %%
grouping = pd.qcut(frame.data1, 10, labels=False)

# %%
grouping = pd.qcut(frame.data1, 10)

# %%
grouped = frame.data2.groupby(grouping)

# %%
list(grouped)

# %%
grouped.apply(get_stats).unstack()

# %% [markdown]
# ## 10.3.3 示例：使用指定分组值填充缺失值

# %%
s = pd.Series(np.random.randn(6))

# %%
s[::2] = np.nan

# %%
s

# %%
s.fillna(s.mean())

# %%
states = [
    'ohio', 'new york', 'vermont', 'Florida',
    'oregon', 'nevada', 'california', 'idaho'
]

# %%
group_key = ['East']*4 + ['West']*4

# %%
group_key

# %%
data = pd.Series(np.random.randn(8), index=states)

# %%
data

# %%
data[['vermont', 'nevada', 'idaho']] = np.nan

# %%
data

# %%
list(data.groupby(group_key))

# %%
fill_mean = lambda g: g.fillna(g.mean)

# %%
data.groupby(group_key).apply(fill_mean)

# %%
fill_values = {'East':0.5, 'West':-1}

# %%
fill_func = lambda g: g.fillna(fill_values[g.name])

# %%
data.groupby(group_key).apply(fill_func)

# %% [markdown]
# ## 10.3.4 示例：随机采样与排列

# %%
suits = ['H','S','C','D']

# %%
card_val = (list(range(1,11)) + [10]*3) * 4

# %%
base_names = ['A'] + list(range(2,11)) + ['J','Q','K']

# %%
base_names

# %%
cards = []

# %%
for suit in suits:
    cards.extend(str(num) + suit for num in base_names)

# %%
len(cards)

# %%
deck = pd.Series(card_val, index=cards)

# %%
deck[:13]

# %%
def draw(deck, n=5):
    return deck.sample(n)

# %%
draw(deck)

# %%
get_suit = lambda card: card[-1]

# %%
list(deck.groupby(get_suit))

# %%
deck.groupby(get_suit).apply(draw, n=2)

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n=2)

# %% [markdown]
# ## 10.3.5 示例： 分组加权平均和相关性

# %%
df = pd.DataFrame({
    'category': list('aaaabbbb'),
    'data': np.random.randn(8),
    'weights': np.random.randn(8)
})

# %%
df
# Out:
#   category      data   weights
# 0        a  2.677925 -0.097304
# 1        a -0.611409 -0.605925
# 2        a -0.358159 -0.058244
# 3        a  0.490531 -0.506694
# 4        b  1.504641 -0.157183
# 5        b  1.009209 -2.074929
# 6        b  0.679475  0.797549
# 7        b  0.772978 -0.725414

# %%
grouped = df.groupby('category')

# %%
get_wavg = lambda g: np.average(g['data'], weights = g['weights'])

# %%
grouped.apply(get_wavg)
# Out:
# category
# a    0.092883
# b    1.087676
# dtype: float64

# %%
close_px = pd.read_csv('examples/stock_px_2.csv', parse_dates=True, index_col=0)

# %%
close_px[:10]
# Out:
#             AAPL   MSFT    XOM     SPX
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59
# 2003-01-06  7.45  21.52  29.96  929.01
# 2003-01-07  7.43  21.93  28.95  922.93
# 2003-01-08  7.28  21.31  28.83  909.93
# 2003-01-09  7.34  21.93  29.44  927.57
# 2003-01-10  7.36  21.97  29.03  927.57
# 2003-01-13  7.32  22.16  28.91  926.26
# 2003-01-14  7.30  22.39  29.17  931.66
# 2003-01-15  7.22  22.11  28.77  918.22

# %%
# !type examples\stock_px_2.csv
# Out:
# ,AAPL,MSFT,XOM,SPX
# 2003-01-02 00:00:00,7.4,21.11,29.22,909.03
# 2003-01-03 00:00:00,7.45,21.14,29.24,908.59
# 2003-01-06 00:00:00,7.45,21.52,29.96,929.01
# 2003-01-07 00:00:00,7.43,21.93,28.95,922.93
# 2003-01-08 00:00:00,7.28,21.31,28.83,909.93
# 2003-01-09 00:00:00,7.34,21.93,29.44,927.57
# 2003-01-10 00:00:00,7.36,21.97,29.03,927.57
# 2003-01-13 00:00:00,7.32,22.16,28.91,926.26
# 2003-01-14 00:00:00,7.3,22.39,29.17,931.66
# 2003-01-15 00:00:00,7.22,22.11,28.77,918.22
# 2003-01-16 00:00:00,7.31,21.75,28.9,914.6
# 2003-01-17 00:00:00,7.05,20.22,28.6,901.78
# 2003-01-21 00:00:00,7.01,20.17,27.94,887.62
# 2003-01-22 00:00:00,6.94,20.04,27.58,878.36
# 2003-01-23 00:00:00,7.09,20.54,27.52,887.34
# 2003-01-24 00:00:00,6.9,19.59,26.93,861.4
# 2003-01-27 00:00:00,7.07,19.32,26.21,847.48
# 2003-01-28 00:00:00,7.29,19.18,26.9,858.54
# 2003-01-29 00:00:00,7.47,19.61,27.88,864.36
# 2003-01-30 00:00:00,7.16,18.95,27.37,844.61
# 2003-01-31 00:00:00,7.18,18.65,28.13,855.7
# ...

# %%
close_px.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB

# %%
close_px[:6]
# Out:
#             AAPL   MSFT    XOM     SPX
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59
# 2003-01-06  7.45  21.52  29.96  929.01
# 2003-01-07  7.43  21.93  28.95  922.93
# 2003-01-08  7.28  21.31  28.83  909.93
# 2003-01-09  7.34  21.93  29.44  927.57

# %%
spx_corr = lambda x: x.corrwith(x['SPX'])

# %%
rets = close_px.pct_change().dropna()
rets
# Out:
#                 AAPL      MSFT       XOM       SPX
# 2003-01-03  0.006757  0.001421  0.000684 -0.000484
# 2003-01-06  0.000000  0.017975  0.024624  0.022474
# 2003-01-07 -0.002685  0.019052 -0.033712 -0.006545
# 2003-01-08 -0.020188 -0.028272 -0.004145 -0.014086
# 2003-01-09  0.008242  0.029094  0.021159  0.019386
# ...              ...       ...       ...       ...
# 2011-10-10  0.051406  0.026286  0.036977  0.034125
# 2011-10-11  0.029526  0.002227 -0.000131  0.000544
# 2011-10-12  0.004747 -0.001481  0.011669  0.009795
# 2011-10-13  0.015515  0.008160 -0.010238 -0.002974
# 2011-10-14  0.033225  0.003311  0.022784  0.017380
#
# [2213 rows x 4 columns]

# %%
get_year = lambda x: x.year

# %%
by_year = rets.groupby(get_year)

# %%
list(by_year)
# Out:
# [(2003,
#                   AAPL      MSFT       XOM       SPX
#   2003-01-03  0.006757  0.001421  0.000684 -0.000484
#   2003-01-06  0.000000  0.017975  0.024624  0.022474
#   2003-01-07 -0.002685  0.019052 -0.033712 -0.006545
#   2003-01-08 -0.020188 -0.028272 -0.004145 -0.014086
#   2003-01-09  0.008242  0.029094  0.021159  0.019386
#   ...              ...       ...       ...       ...
#   2003-12-24  0.030303 -0.003717  0.002080 -0.001807
#   2003-12-26  0.018627  0.006063  0.005336  0.001691
#   2003-12-29  0.017324  0.009272  0.013270  0.012401
#   2003-12-30  0.006623  0.002297  0.002619  0.000144
#   2003-12-31  0.004699 -0.005500  0.007837  0.002055
#
#   [251 rows x 4 columns]),
#  (2004,
#                   AAPL      MSFT       XOM       SPX
#   2004-01-02 -0.004677  0.002765 -0.008929 -0.003094
#   2004-01-05  0.042293  0.025276  0.023249  0.012395
#   2004-01-06 -0.003607  0.003586 -0.006816  0.001292
#   2004-01-07  0.022624 -0.001340 -0.007149  0.002367
# ...

# %%
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
by_year.apply(lambda g: g['AAPL'].corr(g['MSFT']))
# Out:
# 2003    0.480868
# 2004    0.259024
# 2005    0.300093
# 2006    0.161735
# 2007    0.417738
# 2008    0.611901
# 2009    0.432738
# 2010    0.571946
# 2011    0.581987
# dtype: float64

# %% [markdown]
# ## 10.3.6 示例: 逐组线性回归

# %%
import statsmodels.api as sm

# %%
def regress(data, yvar, xvars):
    Y = data[yvar]
    X = data[xvars]
    X['intercept'] = 1
    result = sm.OLS(Y, X).fit()
    return result.params

# %%
by_year.apply(regress, 'AAPL', ['SPX'])
# Out:
#            SPX  intercept
# 2003  1.195406   0.000710
# 2004  1.363463   0.004201
# 2005  1.766415   0.003246
# 2006  1.645496   0.000080
# 2007  1.198761   0.003438
# 2008  0.968016  -0.001110
# 2009  0.879103   0.002954
# 2010  1.052608   0.001261
# 2011  0.806605   0.001514

# %% [markdown]
# # 10.4 数据透视表与交叉表

# %%
list(tips.groupby(['day', 'smoker']))
# Out:
# [(('Fri', 'No'),
#        total_bill   tip smoker  day    time  size   tip_pct
#   91        22.49  3.50     No  Fri  Dinner     2  0.155625
#   94        22.75  3.25     No  Fri  Dinner     2  0.142857
#   99        12.46  1.50     No  Fri  Dinner     2  0.120385
#   223       15.98  3.00     No  Fri   Lunch     3  0.187735),
#  (('Fri', 'Yes'),
#        total_bill   tip smoker  day    time  size   tip_pct
#   90        28.97  3.00    Yes  Fri  Dinner     2  0.103555
#   92         5.75  1.00    Yes  Fri  Dinner     2  0.173913
#   93        16.32  4.30    Yes  Fri  Dinner     2  0.263480
#   95        40.17  4.73    Yes  Fri  Dinner     4  0.117750
#   96        27.28  4.00    Yes  Fri  Dinner     2  0.146628
#   97        12.03  1.50    Yes  Fri  Dinner     2  0.124688
#   98        21.01  3.00    Yes  Fri  Dinner     2  0.142789
#   100       11.35  2.50    Yes  Fri  Dinner     2  0.220264
#   101       15.38  3.00    Yes  Fri  Dinner     2  0.195059
# ...

# %%
tips.pivot_table(index=['day', 'smoker'])
# Out:
#                  size       tip   tip_pct  total_bill
# day  smoker
# Fri  No      2.250000  2.812500  0.151650   18.420000
#      Yes     2.066667  2.714000  0.174783   16.813333
# Sat  No      2.555556  3.102889  0.158048   19.661778
#      Yes     2.476190  2.875476  0.147906   21.276667
# Sun  No      2.929825  3.167895  0.160113   20.506667
#      Yes     2.578947  3.516842  0.187250   24.120000
# Thur No      2.488889  2.673778  0.160298   17.113111
#      Yes     2.352941  3.030000  0.163863   19.190588

# %%
tips[:5]
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808

# %%
2.0+2.2222222222
# Out:
# 4.2222222222

# %%
4.2222222222/2
# Out:
# 2.1111111111

# %%
tips.pivot_table( index=['time', 'day'], columns='smoker')
# Out:
#                  size                 tip             tip_pct            \
# smoker             No       Yes        No       Yes        No       Yes
# time   day
# Dinner Fri   2.000000  2.222222  2.750000  3.003333  0.139622  0.165347
#        Sat   2.555556  2.476190  3.102889  2.875476  0.158048  0.147906
#        Sun   2.929825  2.578947  3.167895  3.516842  0.160113  0.187250
#        Thur  2.000000       NaN  3.000000       NaN  0.159744       NaN
# Lunch  Fri   3.000000  1.833333  3.000000  2.280000  0.187735  0.188937
#        Thur  2.500000  2.352941  2.666364  3.030000  0.160311  0.163863
#
#             total_bill
# smoker              No        Yes
# time   day
# Dinner Fri   19.233333  19.806667
#        Sat   19.661778  21.276667
#        Sun   20.506667  24.120000
#        Thur  18.780000        NaN
# Lunch  Fri   15.980000  12.323333
#        Thur  17.075227  19.190588

# %%
tips.pivot_table( index=['time', 'day'], columns='smoker', margins=True)
# Out:
#                  size                           tip                      \
# smoker             No       Yes       All        No       Yes       All
# time   day
# Dinner Fri   2.000000  2.222222  2.166667  2.750000  3.003333  2.940000
#        Sat   2.555556  2.476190  2.517241  3.102889  2.875476  2.993103
#        Sun   2.929825  2.578947  2.842105  3.167895  3.516842  3.255132
#        Thur  2.000000       NaN  2.000000  3.000000       NaN  3.000000
# Lunch  Fri   3.000000  1.833333  2.000000  3.000000  2.280000  2.382857
#        Thur  2.500000  2.352941  2.459016  2.666364  3.030000  2.767705
# All          2.668874  2.408602  2.569672  2.991854  3.008710  2.998279
#
#               tip_pct                     total_bill
# smoker             No       Yes       All         No        Yes        All
# time   day
# Dinner Fri   0.139622  0.165347  0.158916  19.233333  19.806667  19.663333
#        Sat   0.158048  0.147906  0.153152  19.661778  21.276667  20.441379
# ...

# %%
2.166667*2
# Out:
# 4.333334

# %%
tips.pivot_table('tip_pct', index=['time', 'smoker'], columns = 'day', aggfunc=len, margins=True)
# Out:
# day             Fri   Sat   Sun  Thur    All
# time   smoker
# Dinner No       3.0  45.0  57.0   1.0  106.0
#        Yes      9.0  42.0  19.0   NaN   70.0
# Lunch  No       1.0   NaN   NaN  44.0   45.0
#        Yes      6.0   NaN   NaN  17.0   23.0
# All            19.0  87.0  76.0  62.0  244.0

# %%
tips.pivot_table('tip_pct', index=['time', 'size', 'smoker'], columns='day', aggfunc='mean', fill_value=0)
# Out:
# day                      Fri       Sat       Sun      Thur
# time   size smoker
# Dinner 1    No      0.000000  0.137931  0.000000  0.000000
#             Yes     0.000000  0.325733  0.000000  0.000000
#        2    No      0.139622  0.162705  0.168859  0.159744
#             Yes     0.171297  0.148668  0.207893  0.000000
#        3    No      0.000000  0.154661  0.152663  0.000000
#             Yes     0.000000  0.144995  0.152660  0.000000
#        4    No      0.000000  0.150096  0.148143  0.000000
#             Yes     0.117750  0.124515  0.193370  0.000000
#        5    No      0.000000  0.000000  0.206928  0.000000
#             Yes     0.000000  0.106572  0.065660  0.000000
#        6    No      0.000000  0.000000  0.103799  0.000000
# Lunch  1    No      0.000000  0.000000  0.000000  0.181728
#             Yes     0.223776  0.000000  0.000000  0.000000
#        2    No      0.000000  0.000000  0.000000  0.166005
#             Yes     0.181969  0.000000  0.000000  0.158843
# ...

# %%
tips.pivot_table('tip_pct', index=['time', 'smoker'], columns = 'day', aggfunc=len, margins=True)
# Out:
# day             Fri   Sat   Sun  Thur    All
# time   smoker
# Dinner No       3.0  45.0  57.0   1.0  106.0
#        Yes      9.0  42.0  19.0   NaN   70.0
# Lunch  No       1.0   NaN   NaN  44.0   45.0
#        Yes      6.0   NaN   NaN  17.0   23.0
# All            19.0  87.0  76.0  62.0  244.0

# %%
tips.pivot_table('tip_pct', index=['time', 'smoker'], columns = 'day', aggfunc='mean', margins=True)
# Out:
# day                 Fri       Sat       Sun      Thur       All
# time   smoker
# Dinner No      0.139622  0.158048  0.160113  0.159744  0.158653
#        Yes     0.165347  0.147906  0.187250       NaN  0.160828
# Lunch  No      0.187735       NaN       NaN  0.160311  0.160920
#        Yes     0.188937       NaN       NaN  0.163863  0.170404
# All            0.169913  0.153152  0.166897  0.161276  0.160803

# %% [markdown]
# ## 10.4.1 交叉表：crosstab

# %%
data = pd.DataFrame({
    'Sample': np.arange(1,11),
    'Nationality': 'usa japan usa japan japan japan usa usa japan usa'.split(),
    'Handedness': 'right_handed left_handed right_handed right_handed left_handed right_handed right_handed left_handed right_handed right_handed '.split()
})

# %%
data
# Out:
#    Sample Nationality    Handedness
# 0       1         usa  right_handed
# 1       2       japan   left_handed
# 2       3         usa  right_handed
# 3       4       japan  right_handed
# 4       5       japan   left_handed
# 5       6       japan  right_handed
# 6       7         usa  right_handed
# 7       8         usa   left_handed
# 8       9       japan  right_handed
# 9      10         usa  right_handed

# %%
pd.crosstab(data.Nationality, data.Handedness, margins=True)
# Out:
# Handedness   left_handed  right_handed  All
# Nationality
# japan                  2             3    5
# usa                    1             4    5
# All                    3             7   10

# %%
pd.crosstab([tips.time, tips.day], tips.smoker, margins=True)
# Out:
# smoker        No  Yes  All
# time   day
# Dinner Fri     3    9   12
#        Sat    45   42   87
#        Sun    57   19   76
#        Thur    1    0    1
# Lunch  Fri     1    6    7
#        Thur   44   17   61
# All          151   93  244

# %% [markdown]
# # 10.5 本章小结

# %%
#  数据分组工具可以帮助我们清洗数据
